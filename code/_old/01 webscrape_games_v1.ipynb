# %% [markdown]
# # Webscrape NFL Games, Weather

# %% [markdown]
# ### Set-up

# %%
# Import packages
import pandas as pd
import numpy as np
import string
from bs4 import BeautifulSoup
import requests
import time
import os
import sys

# Directory
WORKING_DIRECTORY = "SET WD HERE"

# %% [markdown]
# ### Set relevant web scraping info

# %%
# Get weeks of season to check
preseason_wks = ["Pre Season Week " + str(x) for x in list(range(1, 5))]
regular_wks = ["Week " + str(x) for x in list(range(1, 19))]
other_wks = ["Wildcard Weekend", "Divisional Playoffs", "Conf Championships", "Pro Bowl", "Superbowl"]
all_wks = preseason_wks + regular_wks + other_wks

# Seasons to check
seasons = list(range(2009, 2024))

# Main webpage
webpage_main = "https://www.nflweather.com/week/"

# %% [markdown]
# ### Web scrape

# %%
game_df = pd.DataFrame()
for season in seasons:
    try:
        if season == 2010:
            webpage = webpage_main + str(season) + "/week-1-2"
        else:
            webpage = webpage_main + str(season) + "/week-1"
        
        response = requests.get(webpage)
        soup = BeautifulSoup(response.text, 'html.parser')
        
        # Get season-week options
        weeks_raw = soup.find_all("option")
        weeks = []
        for week in weeks_raw:
            week_val = week["value"]
            if week_val == "2023":
                break
            weeks.append(week_val)

        for wk in weeks:
            webpage = webpage_main + str(season) + "/" + wk
            # Make request
            response = requests.get(webpage)
            soup = BeautifulSoup(response.text, 'html.parser')
            
            # Relevant attributes
            sp_points = soup.find_all("div", {"class": "game-points"}) # Points
            sp_teams = soup.find_all("a", {"class": "text-dark"}) # Teams
            sp_dome = soup.find_all("img", {"class": "game-box-weather-image"}) # Dome
            sp_weather = soup.find_all("div", {"class": "mx-2"}) # Weather
            
            #--- Clean each attribute ---#
            
            # Points
            team_1_pts = []
            team_2_pts = []
            for i in range(0, len(sp_points)):
                if (i + 1) % 2 != 0:
                    team_1_pts.append(sp_points[i].get_text())
                else:
                    team_2_pts.append(sp_points[i].get_text())
            
            # Teams
            teams = []
            for i in range(0, len(sp_teams)):
                if (i + 1) % 3 == 0:
                    teams.append(sp_teams[i]["title"])
                    
            # Dome/stadium type
            dome = []
            for i in sp_dome:
                dome_type = i["src"]
                dome.append(dome_type)
                
            # Weather
            temperature = []
            other_conditions = []
            for i in range(0, len(sp_weather)):
                if (i + 1) % 2 != 0:
                    temperature.append(sp_weather[i].get_text())
                else:
                    other_conditions.append(sp_weather[i].get_text())   
            
            #--- Add attributes to dataframe ---#
            df = pd.DataFrame(
                {'teams':teams,
                 'team 1 pts':team_1_pts,
                 'team 2 pts':team_2_pts,
                 'dome':dome,
                 'temp': temperature,
                 'conditions':other_conditions
                 })
            
            df['week'] = wk
            df['season'] = season
            
            game_df = pd.concat([game_df, df])
            
            time.sleep(1) # Time buffer between webpage calls
            print(str(season) + " " + wk)
    except:
        continue
# Out:
# 2009 pre-season-week-1
# 2009 pre-season-week-2
# 2009 pre-season-week-3
# 2009 pre-season-week-4
# 2009 week-1
# 2009 week-2
# 2009 week-3
# 2009 week-4
# 2009 week-5
# 2009 week-6
# 2009 week-7
# 2009 week-8
# 2009 week-9
# 2009 week-10
# 2009 week-11
# 2009 week-12
# 2009 week-13
# 2009 week-14
# 2009 week-15
# 2009 week-16
# 2009 week-17
# 2009 wildcard-weekend
# 2009 divisional-playoffs
# 2009 conf-championships
# 2009 pro-bowl
# 2009 superbowl
# 2010 pre-season-week-1-2
# 2010 pre-season-week-2-2
# 2010 pre-season-week-3-2
# 2010 pre-season-week-4-2
# 2010 week-1-2
# 2010 week-2-2
# 2010 week-3-2
# 2010 week-4-2
# 2010 week-5-2
# 2010 week-6-2
# 2010 week-7-2
# 2010 week-8-2
# 2010 week-9-2
# 2010 week-10-2
# 2010 week-11-2
# 2010 week-12-2
# 2010 week-13-2
# 2010 week-14-2
# 2010 week-15-2
# 2010 week-16-2
# 2010 week-17-2
# 2010 wildcard-weekend-2
# 2010 divisional-playoffs-2
# 2010 conf-championships-2
# 2010 pro-bowl-2
# 2010 superbowl-2
# 2011 pre-season-week-1
# 2011 pre-season-week-2
# 2011 pre-season-week-3
# 2011 pre-season-week-4
# 2011 week-1
# 2011 week-2
# 2011 week-3
# 2011 week-4
# 2011 week-5
# 2011 week-6
# 2011 week-7
# 2011 week-8
# 2011 week-9
# 2011 week-10
# 2011 week-11
# 2011 week-12
# 2011 week-13
# 2011 week-14
# 2011 week-15
# 2011 week-16
# 2011 week-17
# 2011 wildcard-weekend
# 2011 divisional-playoffs
# 2011 conf-championships
# 2011 pro-bowl
# 2011 superbowl
# 2012 pre-season-week-2
# 2012 pre-season-week-3
# 2012 pre-season-week-4
# 2012 week-1
# 2012 week-2
# 2012 week-3
# 2012 week-4
# 2012 week-5
# 2012 week-6
# 2012 week-7
# 2012 week-8
# 2012 week-9
# 2012 week-10
# 2012 week-11
# 2012 week-12
# 2012 week-13
# 2012 week-14
# 2013 divisional-playoffs
# 2013 conf-championships
# 2013 pre-season-week-1
# 2013 pre-season-week-2
# 2013 pre-season-week-3
# 2013 pre-season-week-4
# 2013 week-1
# 2013 week-2
# 2013 week-3
# 2013 week-4
# 2013 week-5
# 2013 week-6
# 2013 week-7
# 2013 week-8
# 2013 week-9
# 2013 week-10
# 2013 week-11
# 2013 week-12
# 2013 week-13
# 2013 week-14
# 2013 week-15
# 2013 week-16
# 2013 week-17
# 2013 wildcard-weekend
# 2013 probowl
# 2013 superbowl
# 2014 pre-season-week-1
# 2014 pre-season-week-2
# 2014 pre-season-week-3
# 2014 pre-season-week-4
# 2014 week-1
# 2014 Week-2
# 2014 Week-3
# 2014 Week-4
# 2014 Week-5
# 2014 Week-6
# 2014 Week-7
# 2014 Week-8
# 2014 Week-9
# 2014 Week-10
# 2014 Week-11
# 2014 Week-12
# 2014 Week-13
# 2014 Week-14
# 2014 Week-15
# 2014 Week-16
# 2014 Week-17
# 2014 wildcard-weekend
# 2014 divisional-playoffs
# 2014 conf-championships
# 2014 pro-bowl
# 2014 superbowl
# 2015 pre-season-week-1
# 2015 pre-season-week-2
# 2015 pre-season-week-3
# 2015 pre-season-week-4
# 2015 week-1
# 2015 week-2
# 2015 week-3
# 2015 week-4
# 2015 week-5
# 2015 week-6
# 2015 week-7
# 2015 week-8
# 2015 week-9
# 2015 week-10
# 2015 week-11
# 2015 week-12
# 2015 week-13
# 2015 week-14
# 2015 week-15
# 2015 week-16
# 2015 week-17
# 2015 wildcard-weekend
# 2015 divisional-playoffs
# 2015 conf-championships
# 2015 pro-bowl
# 2015 superbowl
# 2016 pre-season-week-1
# 2016 pre-season-week-2
# 2016 pre-season-week-3
# 2016 pre-season-week-4
# 2016 week-1
# 2016 week-2
# 2016 week-3
# 2016 week-4
# 2016 week-5
# 2016 week-6
# 2016 week-7
# 2016 week-8
# 2016 week-9
# 2016 week-10
# 2016 week-11
# 2016 week-12
# 2016 week-13
# 2016 week-14
# 2016 week-15
# 2016 week-16
# 2016 week-17
# 2016 wildcard-weekend
# 2016 divisional-playoffs
# 2016 conf-championships
# 2016 pro-bowl
# 2016 superbowl
# 2017 pre-season-week-1
# 2017 pre-season-week-2
# 2017 pre-season-week-3
# 2017 pre-season-week-4
# 2017 week-1
# 2017 week-2
# 2017 week-3
# 2017 week-4
# 2017 week-5
# 2017 week-6
# 2017 week-7
# 2017 week-8
# 2017 week-9
# 2017 week-10
# 2017 week-11
# 2017 week-12
# 2017 week-13
# 2017 week-14
# 2017 week-15
# 2017 week-16
# 2017 week-17
# 2017 wildcard-weekend
# 2017 divisional-playoffs
# 2017 conf-championships
# 2017 pro-bowl
# 2017 superbowl
# 2018 pre-season-week-1
# 2018 pre-season-week-2
# 2018 pre-season-week-3
# 2018 pre-season-week-4
# 2018 week-1
# 2018 week-2
# 2018 week-3
# 2018 week-4
# 2018 week-5
# 2018 week-6
# 2018 week-7
# 2018 week-8
# 2018 week-9
# 2018 week-10
# 2018 week-11
# 2018 week-12
# 2018 week-13
# 2018 week-14
# 2018 week-15
# 2018 week-16
# 2018 week-17
# 2018 wildcard-weekend
# 2018 divisional-playoffs
# 2018 conf-championships
# 2018 pro-bowl
# 2018 superbowl
# 2019 pre-season-week-1
# 2019 pre-season-week-2
# 2019 pre-season-week-3
# 2019 pre-season-week-4
# 2019 week-1
# 2019 week-2
# 2019 week-3
# 2019 week-4
# 2019 week-5
# 2019 week-6
# 2019 week-7
# 2019 week-8
# 2019 week-9
# 2019 week-10
# 2019 week-11
# 2019 week-12
# 2019 week-13
# 2019 week-14
# 2019 week-15
# 2019 week-16
# 2019 week-17
# 2019 wildcard-weekend
# 2019 divisional-playoffs
# 2019  conf-championships
# 2019 pro-bowl
# 2019 superbowl
# 2020 week-1
# 2020 week-2
# 2020 week-3
# 2020 week-4
# 2020 week-5
# 2020 week-6
# 2020 week-7
# 2020 week-8
# 2020 week-9
# 2020 week-10
# 2020 week-11
# 2020 week-12
# 2020 week-13
# 2020 week-14
# 2020 week-15
# 2020 week-16
# 2020 week-17
# 2020 wildcard-weekend
# 2020 divisional-playoffs
# 2020  conf-championships
# 2020 superbowl
# 2021 pre-season-week-1
# 2021 pre-season-week-2
# 2021 pre-season-week-3
# 2021 week-1
# 2021 week-2
# 2021 week-3
# 2021 week-4
# 2021 week-5
# 2021 week-6
# 2021 week-7
# 2021 week-8
# 2021 week-9
# 2021 week-10
# 2021 week-11
# 2021 week-12
# 2021 week-13
# 2021 week-14
# 2021 week-15
# 2021 week-16
# 2021 week-17
# 2021 week-18
# 2021 wildcard-weekend
# 2021 divisional-playoffs
# 2021  conf-championships
# 2021 superbowl
# 2022 pre-season-week-1
# 2022 pre-season-week-2
# 2022 pre-season-week-3
# 2022 week-1
# 2022 week-2
# 2022 week-3
# 2022 week-4
# 2022 week-5
# 2022 week-6
# 2022 week-7
# 2022 week-8
# 2022 week-9
# 2022 week-10
# 2022 week-11
# 2022 week-12
# 2022 week-13
# 2022 week-14
# 2022 week-15
# 2022 week-16
# 2022 week-17
# 2022 week-18
# 2022 wildcard-weekend
# 2022 divisional-playoffs
# 2022  conf-championships
# 2022 superbowl
# 2023 hall-of-fame-weekend
# 2023 preseason-week-1
# 2023 preseason-week-2
# 2023 preseason-week-3
# 2023 week-1
# 2023 week-2
# 2023 week-3

# %%
game_df
# Out:
#                                                 teams team 1 pts team 2 pts  \
# 0     Click to see more details about Bills at Titans         18         21
# 1   Click to see more details about Patriots at Ea...         27         25
# 2   Click to see more details about Redskins at Ra...          0         23
# 3   Click to see more details about Cardinals at S...         10         20
# 4   Click to see more details about Cowboys at Rai...         10         31
# ..                                                ...        ...        ...
# 11    Click to see more details about Bears At Chiefs         10         41
# 12  Click to see more details about Cowboys At Car...         16         28
# 13  Click to see more details about Steelers At Ra...         23         18
# 14  Click to see more details about Eagles At Bucc...         25         11
# 15    Click to see more details about Rams At Bengals         16         19
#
#                              dome   temp     conditions               week  \
# 0               /climates/few.png  87 °F   A Few Clouds  pre-season-week-1
# 1               /climates/sct.png  75 °F  Partly Cloudy  pre-season-week-1
# 2           /climates/scttsra.png  75 °F     Light Rain  pre-season-week-1
# 3               /climates/few.png  73 °F           Fair  pre-season-week-1
# 4               /climates/few.png  70 °F   A Few Clouds  pre-season-week-1
# ..                            ...    ...            ...                ...
# 11            /climates/clear.png  82 °F          Clear             week-3
# 12            /climates/dome.webp  93 °F          Clear             week-3
# 13            /climates/dome.webp  87 °F          Clear             week-3
# 14  /climates/mostly_cloudy_n.png  87 °F  Mostly Cloudy             week-3
# 15          /climates/clear_n.png  68 °F          Clear             week-3
#
#     season
# 0     2009
# 1     2009
# 2     2009
# 3     2009
# 4     2009
# ..     ...
# 11    2023
# 12    2023
# 13    2023
# 14    2023
# 15    2023
#
# [4615 rows x 8 columns]

# %%
season = seasons[0]
wk = all_wks[0]
wk_lower_cleaned = wk.lower().replace(" ", "-")
webpage = webpage_main + str(season) + "/" + wk_lower_cleaned

# Make request
response = requests.get(webpage)
soup = BeautifulSoup(response.text, 'html.parser')
            
# Relevant attributes
sp_points = soup.find_all("div", {"class": "game-points"}) # Points
sp_teams = soup.find_all("a", {"class": "text-dark"}) # Teams
sp_dome = soup.find_all("img", {"class": "game-box-weather-image"}) # Dome
sp_weather = soup.find_all("div", {"class": "mx-2"}) # Weather

# %%
game_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
webpage = "https://www.nflweather.com/week/2020/week-3"
response = requests.get(webpage)

# %%
soup = BeautifulSoup(response.text, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
# <title>NFLWeather</title>
# <meta content="authenticity_token" name="csrf-param">
# <meta content="/d9Hufee5P3a44jMKT+6fJpVSejStbj6t1/HUqNbAPYm2QeDAYwowOaRK6+J7ZbCsyBITCGw9jL8bPBbZv9nuw==" name="csrf-token">
# <link href="/assets/application-6c07eae901b7d9330386f308e458330c32a2464e59ee46a57e10a482564d7f8c.css" media="all" rel="stylesheet"/>
# <script src="/assets/application-efd0efb8a6acc5ac5dfcb6d8d064af6ad9dd02c595ea24d47bff569dc1f10f10.js"></script>
# <link href="/assets/favicon-139bed0ed1ee258509c67d275498f7443abae55a2186fbc396d7f05d86728f74.ico" rel="shortcut icon" type="image/x-icon"/>
# <meta content="NFLWeather" property="og:title"/>
# <meta content="NFLWeather.com™ is the only place to receive every weather forecast, updated twice an hour, for every football game every week." property="og:description"/>
# <meta content="https://www.nflweather.com/logo_small.png" property="og:image"/>
# <meta content="https://www.nflweather.com/" property="og:url"/>
# <meta content="website" property="og:type"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="NFLWeather" name="twitter:title"/>
# <meta content="NFLWeather.com™ is the only place to receive every weather forecast, updated twice an hour, for every football game every week." name="twitter:description"/>
# <meta content="https://www.nflweather.com/logo_small.png" name="twitter:image"/>
# </meta></meta></head>
# <!-- Google tag (gtag.js) -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-LKDXXNBTXG"></script>
# <script>
#     window.dataLayer = window.dataLayer || [];
#     function gtag(){dataLayer.push(arguments);}
#     gtag('js', new Date());
#
#     gtag('config', 'G-LKDXXNBTXG');
#   </script>
# <body class="d-flex flex-column min-vh-100">
# <nav class="navbar navbar-expand-lg navbar-dark bg-dark header-container-links" id="menu-nav">
# <div class="container-fluid">
# <a class="navbar-brand" href="#"></a>
# <button aria-controls="navbarNavDropdown" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-bs-target="#navbarNavDropdown" data-bs-toggle="collapse" type="button">
# <span class="navbar-toggler-icon"></span>
# </button>
# <div class="collapse navbar-collapse justify-content-center" id="navbarNavDropdown">
# <ul class="navbar-nav">
# <li class="nav-item">
# <a class="nav-link" href="/">HOME</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="/archive" target="_blank">ANALYTICS</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="/team_forecast" target="_blank">TEAM SCHEDULES</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="/stadium_forecast" target="_blank">STADIUMS</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="/pickem_leaders" target="_blank">PICK'EM LEADERS</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="/news" target="_blank">NEWS</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="/widgets" target="_blank">FREE WIDGETS</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="/users/sign_in">LOG IN</a>
# </li>
# </ul>
# </div>
# </div>
# </nav>
# <div class="text-center">
# <a href="/">
# <img class="w-100 d-block d-lg-none" src="/banner_mobile.webp"/>
# <img class="w-100 d-none d-lg-block" src="/banner_web.webp"/>
# </a></div>
# <div class="container">
# <div class="title d-none">
# <span class="material-icons title-icon">sports_football</span>
#     Week 3
#   </div>
# <div class="row flex-centered mt-3">
# <div class="col-md-6 col-xl-4 flex-centered">
# <div class="week-btn flex-centered" data-navigate="previous" title="Previous Week"><span class="material-icons">navigate_before</span></div>
# <form accept-charset="UTF-8" action="/week/2020/week-3" data-remote="true" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="b7nyGl2M1K4cdNiHFBKZUJT/kA0lcjfSV2knK0Aw+/jJEjZ/RKOlUI4z99E+iDTtqC7KMGumURatao9PtcKJiA=="/>
# <select class="form-select my-2 select-week text-center" id="week_selector" name="week_selector"><option value="week-1">Week 1</option>
# <option value="week-2">Week 2</option>
# <option selected="selected" value="week-3">Week 3</option>
# <option value="week-4">Week 4</option>
# <option value="week-5">Week 5</option>
# <option value="week-6">Week 6</option>
# <option value="week-7">Week 7</option>
# <option value="week-8">Week 8</option>
# <option value="week-9">Week 9</option>
# <option value="week-10">Week 10</option>
# <option value="week-11">Week 11</option>
# <option value="week-12">Week 12</option>
# <option value="week-13">Week 13</option>
# <option value="week-14">Week 14</option>
# <option value="week-15">Week 15</option>
# <option value="week-16">Week 16</option>
# <option value="week-17">Week 17</option>
# <option value="wildcard-weekend">Wildcard Weekend</option>
# <option value="divisional-playoffs">Divisional Playoffs</option>
# <option value=" conf-championships">Conf Championships</option>
# <option value="superbowl">Superbowl</option></select>
# </form> <div class="week-btn d-flex d-md-none flex-centered" data-navigate="next" title="Next Week"><span class="material-icons">navigate_next</span></div>
# </div>
# <div class="col-10 col-sm-8 col-md-3 col-lg-2">
# <form accept-charset="UTF-8" action="/week/2020/week-3" data-remote="true" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="heTzC835S62UzKCay9vIaoeB++Qjz63izvTBsTm/Y6kjTzdu1NY6UwaLj8zhQWXXu1Ch2W0byyY092nVzE0R2Q=="/>
# <select class="form-select my-2 select-week text-center" id="season_selector" name="season_selector"><option value="2023">2023</option>
# <option value="2022">2022</option>
# <option value="2021">2021</option>
# <option selected="selected" value="2020">2020</option>
# <option value="2019">2019</option>
# <option value="2018">2018</option>
# <option value="2017">2017</option>
# <option value="2016">2016</option>
# <option value="2015">2015</option>
# <option value="2014">2014</option>
# <option value="2013">2013</option>
# <option value="2012">2012</option>
# <option value="2011">2011</option>
# <option value="2010">2010</option>
# <option value="2009">2009</option></select>
# </form> </div>
# <div class="week-btn d-none d-md-flex flex-centered" data-navigate="next" title="Next Week"><span class="material-icons">navigate_next</span></div>
# </div>
# <script type="text/javascript">
#   $('#season_selector').change(function() {
#     let season = $('#season_selector').val();
#     let week = $('#week_selector').val();
#     Rails.ajax({
#       url: "/seasons/check_week",
#       type: "get",
#       data: "season=" + season + "&week=" + week,
#       success: (response) => {
#         window.location = "/week/" + season + "/" + response.week
#       }
#     })
#   });
#   $('#week_selector').change(function() {
#     let season = $('#season_selector').val();
#     let week = $('#week_selector').val();
#     window.location = "/week/" + season + "/" + week
#   });
#   $('.week-btn').click(function(){
#     let nav = $(this).attr('data-navigate')
#     let season = $('#season_selector').val();
#     let week_selected = $('#week_selector').find(":selected")
#     if (nav == 'previous'){
#       prev_week = week_selected.prev().val()
#       if (prev_week){
#         window.location = "/week/" + season + "/" + prev_week
#       }
#     }else if(nav == 'next'){
#       next_week = week_selected.next().val()
#       if (next_week){
#         window.location = "/week/" + season + "/" + next_week
#       }
#     }
#   })
#
# </script>
# <div class="container my-3 text-center overflow-hidden"><div style="max-width:100%"><script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script> <div id="gpt-passback"> <script>      window.googletag = window.googletag || {cmd: []};      googletag.cmd.push(function() {      googletag.defineSlot('/7103,22864402389/SMG_NFLWeather/728x90_1a/sports', [728, 90], 'gpt-passback').addService(googletag.pubads());      googletag.enableServices();      googletag.display('gpt-passback');      });    </script> </div></div></div>
# <div class="container-game-important flex-centered flex-wrap">
# </div>
# </div>
# <div class="container-game-box">
# <div class="game-box w-100 d-flex flex-column flex-lg-row align-items-center shadow-box rounded my-2 py-1" style="">
# <div class="col-12 col-lg-2 text-center py-lg-0 game-kickoff-status px-3">
# <div class="fw-bold text-wrap">
# 			09/24/20 08:20 PM EDT
# 		</div>
# <div class="text-center text-secondary flex-centered">
# <span>Final</span>
#
# 		</div>
# </div>
# <div class="col-12 col-lg-3 text-center flex-centered flex-column flex-lg-row">
# <div class="d-flex justify-content-center align-items-center col-lg-12 px-3">
# <div class="team-game-box justify-content-lg-end">
# <div class="flex-centered flex-column-reverse flex-xxl-row flex-grow-1">
# <div class="flex-centered flex-column me-1 ms-xxl-auto">
# <a class="text-dark" href="/team/dolphins" target="_blank" title="Click to see more details about Miami Dolphins">
# <img class="helmet" src="/uploads/team/away_helmet/11/small_miami.png"/>
# </a> <span class="fw-bold">Dolphins</span>
# </div>
# </div>
# <div class="game-points ps-1 pe-2"></div>
# </div>
# <span class="fw-bold teams-separator">@</span>
# <div class="team-game-box">
# <div class="game-points pe-1 ps-2"></div>
# <div class="flex-centered flex-column flex-xxl-row flex-grow-1">
# <div class="flex-centered flex-column me-xxl-auto">
# <a class="text-dark" href="/team/jaguars" target="_blank" title="Click to see more details about Jacksonville Jaguars">
# <img class="helmet" src="/uploads/team/home_helmet/8/small_h_jacksonville.png"/>
# </a> <span class="fw-bold ms-1">Jaguars</span>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-12 col-lg-7 flex-centered info-game-box pe-3 rounded-end">
# <div class="row flex-centered py-3 py-lg-2 flex-column flex-sm-row game-info w-100">
# <div class="text-center col-12 col-lg-2">
# <a class="text-dark" href="/games/2020/week-3/dolphins-at-jaguars" target="_blank" title="Click to see more details about Dolphins at Jaguars">
# <div class="image-container">
# <img class="game-box-weather-image bg-night rounded" src="/climates/clear-night.png"/>
# </div>
# </a> </div>
# <div class="text-break #&lt;WeatherReport:0x00007fb7308db000&gt; col-md-4 d-flex text-center justify-content-center flex-column">
# <div class="mx-2"><span class="">80 °F</span></div>
# <div class="mx-2"><span class="">Humid</span></div>
# </div>
# <div class="text-break col-md-4 mb-1 px-1 flex-centered">
# <span class="material-icons icon-weather">air</span> <span class="">8 mph  <span class="material-icons md-18">south_east</span>  SE</span>
# </div>
# <div class="col-md-4 col-lg-2 mb-2 mb-md-0 px-1 flex-centered justify-content-center justify-content-lg-start">
# <span class="material-icons outlined md-18">tv</span> <span class="text-center text-sm-start">NFL NETWORK</span>
# </div>
# </div>
# </div>
# </div>
# <div class="game-box w-100 d-flex flex-column flex-lg-row align-items-center shadow-box rounded my-2 py-1" style="">
# <div class="col-12 col-lg-2 text-center py-lg-0 game-kickoff-status px-3">
# <div class="fw-bold text-wrap">
# 			09/27/20 01:00 PM EDT
# 		</div>
# <div class="text-center text-secondary flex-centered">
# <span>Final</span>
#
# 		</div>
# </div>
# <div class="col-12 col-lg-3 text-center flex-centered flex-column flex-lg-row">
# <div class="d-flex justify-content-center align-items-center col-lg-12 px-3">
# <div class="team-game-box justify-content-lg-end">
# <div class="flex-centered flex-column-reverse flex-xxl-row flex-grow-1">
# <div class="flex-centered flex-column me-1 ms-xxl-auto">
# <a class="text-dark" href="/team/texans" target="_blank" title="Click to see more details about Houston Texans">
# <img class="helmet" src="/uploads/team/away_helmet/17/small_houston.png"/>
# </a> <span class="fw-bold">Texans</span>
# </div>
# </div>
# <div class="game-points ps-1 pe-2"></div>
# </div>
# <span class="fw-bold teams-separator">@</span>
# <div class="team-game-box">
# <div class="game-points pe-1 ps-2"></div>
# <div class="flex-centered flex-column flex-xxl-row flex-grow-1">
# <div class="flex-centered flex-column me-xxl-auto">
# <a class="text-dark" href="/team/steelers" target="_blank" title="Click to see more details about Pittsburgh Steelers">
# <img class="helmet" src="/uploads/team/home_helmet/14/small_pit_blanco.png"/>
# </a> <span class="fw-bold ms-1">Steelers</span>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-12 col-lg-7 flex-centered info-game-box pe-3 rounded-end">
# <div class="row flex-centered py-3 py-lg-2 flex-column flex-sm-row game-info w-100">
# <div class="text-center col-12 col-lg-2">
# <a class="text-dark" href="/games/2020/week-3/texans-at-steelers" target="_blank" title="Click to see more details about Texans At Steelers">
# <div class="image-container">
# <img class="game-box-weather-image bg-day rounded" src="/climates/clear-day.png"/>
# </div>
# </a> </div>
# <div class="text-break #&lt;WeatherReport:0x0000556aba552ec0&gt; col-md-4 d-flex text-center justify-content-center flex-column">
# <div class="mx-2"><span class="">76 °F</span></div>
# <div class="mx-2"><span class="">Clear</span></div>
# </div>
# <div class="text-break col-md-4 mb-1 px-1 flex-centered">
# <span class="material-icons icon-weather">air</span> <span class="">3 mph  <span class="material-icons md-18">south_west</span>  SW</span>
# </div>
# <div class="col-md-4 col-lg-2 mb-2 mb-md-0 px-1 flex-centered justify-content-center justify-content-lg-start">
# <span class="material-icons outlined md-18">tv</span> <span class="text-center text-sm-start">CBS</span>
# </div>
# </div>
# </div>
# </div>
# <div class="game-box w-100 d-flex flex-column flex-lg-row align-items-center shadow-box rounded my-2 py-1" style="">
# <div class="col-12 col-lg-2 text-center py-lg-0 game-kickoff-status px-3">
# <div class="fw-bold text-wrap">
# 			09/27/20 01:00 PM EDT
# 		</div>
# <div class="text-center text-secondary flex-centered">
# <span>Final</span>
#
# 		</div>
# </div>
# <div class="col-12 col-lg-3 text-center flex-centered flex-column flex-lg-row">
# <div class="d-flex justify-content-center align-items-center col-lg-12 px-3">
# <div class="team-game-box justify-content-lg-end">
# <div class="flex-centered flex-column-reverse flex-xxl-row flex-grow-1">
# <div class="flex-centered flex-column me-1 ms-xxl-auto">
# <a class="text-dark" href="/team/bengals" target="_blank" title="Click to see more details about Cincinnati Bengals">
# <img class="helmet" src="/uploads/team/away_helmet/12/small_cincinatti.png"/>
# </a> <span class="fw-bold">Bengals</span>
# </div>
# </div>
# <div class="game-points ps-1 pe-2"></div>
# </div>
# <span class="fw-bold teams-separator">@</span>
# <div class="team-game-box">
# <div class="game-points pe-1 ps-2"></div>
# <div class="flex-centered flex-column flex-xxl-row flex-grow-1">
# <div class="flex-centered flex-column me-xxl-auto">
# <a class="text-dark" href="/team/eagles" target="_blank" title="Click to see more details about Philadelphia Eagles">
# <img class="helmet" src="/uploads/team/home_helmet/22/small_h_philadelphia.png"/>
# </a> <span class="fw-bold ms-1">Eagles</span>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-12 col-lg-7 flex-centered info-game-box pe-3 rounded-end">
# <div class="row flex-centered py-3 py-lg-2 flex-column flex-sm-row game-info w-100">
# <div class="text-center col-12 col-lg-2">
# <a class="text-dark" href="/games/2020/week-3/bengals-at-eagles" target="_blank" title="Click to see more details about Bengals at Eagles">
# <div class="image-container">
# <img class="game-box-weather-image bg-day rounded" src="/climates/partly-cloudy-day.png"/>
# </div>
# </a> </div>
# <div class="text-break #&lt;WeatherReport:0x0000556abad1f9c8&gt; col-md-4 d-flex text-center justify-content-center flex-column">
# <div class="mx-2"><span class="">76 °F</span></div>
# <div class="mx-2"><span class="">Mostly Cloudy</span></div>
# </div>
# <div class="text-break col-md-4 mb-1 px-1 flex-centered">
# <span class="material-icons icon-weather">air</span> <span class="">3 mph  <span class="material-icons md-18">south_east</span>  SE</span>
# </div>
# <div class="col-md-4 col-lg-2 mb-2 mb-md-0 px-1 flex-centered justify-content-center justify-content-lg-start">
# <span class="material-icons outlined md-18">tv</span> <span class="text-center text-sm-start">CBS</span>
# </div>
# </div>
# </div>
# </div>
# <div class="game-box w-100 d-flex flex-column flex-lg-row align-items-center shadow-box rounded my-2 py-1" style="">
# <div class="col-12 col-lg-2 text-center py-lg-0 game-kickoff-status px-3">
# <div class="fw-bold text-wrap">
# 			09/27/20 01:00 PM EDT
# 		</div>
# <div class="text-center text-secondary flex-centered">
# <span>Final</span>
#
# 		</div>
# </div>
# <div class="col-12 col-lg-3 text-center flex-centered flex-column flex-lg-row">
# <div class="d-flex justify-content-center align-items-center col-lg-12 px-3">
# <div class="team-game-box justify-content-lg-end">
# <div class="flex-centered flex-column-reverse flex-xxl-row flex-grow-1">
# <div class="flex-centered flex-column me-1 ms-xxl-auto">
# <a class="text-dark" href="/team/49ers" target="_blank" title="Click to see more details about San Francisco 49ers">
# <img class="helmet" src="/uploads/team/away_helmet/30/small_san_francisco.png"/>
# </a> <span class="fw-bold">49ers</span>
# </div>
# </div>
# <div class="game-points ps-1 pe-2"></div>
# </div>
# <span class="fw-bold teams-separator">@</span>
# <div class="team-game-box">
# <div class="game-points pe-1 ps-2"></div>
# <div class="flex-centered flex-column flex-xxl-row flex-grow-1">
# <div class="flex-centered flex-column me-xxl-auto">
# <a class="text-dark" href="/team/giants" target="_blank" title="Click to see more details about New York G Giants">
# <img class="helmet" src="/uploads/team/home_helmet/21/small_h_new_york.png"/>
# </a> <span class="fw-bold ms-1">Giants</span>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-12 col-lg-7 flex-centered info-game-box pe-3 rounded-end">
# <div class="row flex-centered py-3 py-lg-2 flex-column flex-sm-row game-info w-100">
# <div class="text-center col-12 col-lg-2">
# <a class="text-dark" href="/games/2020/week-3/49ers-at-giants" target="_blank" title="Click to see more details about 49ers at Giants">
# <div class="image-container">
# <img class="game-box-weather-image bg-day rounded" src="/climates/partly-cloudy-day.png"/>
# </div>
# </a> </div>
# <div class="text-break #&lt;WeatherReport:0x0000556abaa19648&gt; col-md-4 d-flex text-center justify-content-center flex-column">
# <div class="mx-2"><span class="">77 °F</span></div>
# <div class="mx-2"><span class="">Partly Cloudy</span></div>
# </div>
# <div class="text-break col-md-4 mb-1 px-1 flex-centered">
# <span class="material-icons icon-weather">air</span> <span class="">4 mph  <span class="material-icons md-18">south_east</span>  SE</span>
# </div>
# <div class="col-md-4 col-lg-2 mb-2 mb-md-0 px-1 flex-centered justify-content-center justify-content-lg-start">
# <span class="material-icons outlined md-18">tv</span> <span class="text-center text-sm-start">FOX</span>
# </div>
# </div>
# </div>
# </div>
# <div class="game-box w-100 d-flex flex-column flex-lg-row align-items-center shadow-box rounded my-2 py-1" style="">
# <div class="col-12 col-lg-2 text-center py-lg-0 game-kickoff-status px-3">
# <div class="fw-bold text-wrap">
# 			09/27/20 01:00 PM EDT
# 		</div>
# <div class="text-center text-secondary flex-centered">
# <span>Final</span>
#
# 		</div>
# </div>
# <div class="col-12 col-lg-3 text-center flex-centered flex-column flex-lg-row">
# <div class="d-flex justify-content-center align-items-center col-lg-12 px-3">
# <div class="team-game-box justify-content-lg-end">
# <div class="flex-centered flex-column-reverse flex-xxl-row flex-grow-1">
# <div class="flex-centered flex-column me-1 ms-xxl-auto">
# <a class="text-dark" href="/team/raiders" target="_blank" title="Click to see more details about Las Vegas Raiders">
# <img class="helmet" src="/uploads/team/away_helmet/19/small_las_vegas.png"/>
# </a> <span class="fw-bold">Raiders</span>
# </div>
# </div>
# <div class="game-points ps-1 pe-2"></div>
# </div>
# <span class="fw-bold teams-separator">@</span>
# <div class="team-game-box">
# <div class="game-points pe-1 ps-2"></div>
# <div class="flex-centered flex-column flex-xxl-row flex-grow-1">
# <div class="flex-centered flex-column me-xxl-auto">
# <a class="text-dark" href="/team/patriots" target="_blank" title="Click to see more details about New England Patriots">
# <img class="helmet" src="/uploads/team/home_helmet/2/small_h_new_england.png"/>
# </a> <span class="fw-bold ms-1">Patriots</span>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-12 col-lg-7 flex-centered info-game-box pe-3 rounded-end">
# <div class="row flex-centered py-3 py-lg-2 flex-column flex-sm-row game-info w-100">
# <div class="text-center col-12 col-lg-2">
# <a class="text-dark" href="/games/2020/week-3/raiders-at-patriots" target="_blank" title="Click to see more details about Raiders at Patriots">
# <div class="image-container">
# <img class="game-box-weather-image bg-day rounded" src="/climates/partly-cloudy-day.png"/>
# </div>
# </a> </div>
# <div class="text-break #&lt;WeatherReport:0x0000556aba492198&gt; col-md-4 d-flex text-center justify-content-center flex-column">
# <div class="mx-2"><span class="">76 °F</span></div>
# <div class="mx-2"><span class="">Mostly Cloudy</span></div>
# </div>
# <div class="text-break col-md-4 mb-1 px-1 flex-centered">
# <span class="material-icons icon-weather">air</span> <span class="">7 mph  <span class="material-icons md-18">south_west</span>  SW</span>
# </div>
# <div class="col-md-4 col-lg-2 mb-2 mb-md-0 px-1 flex-centered justify-content-center justify-content-lg-start">
# <span class="material-icons outlined md-18">tv</span> <span class="text-center text-sm-start">CBS</span>
# </div>
# </div>
# </div>
# </div>
# <div class="game-box w-100 d-flex flex-column flex-lg-row align-items-center shadow-box rounded my-2 py-1" style="">
# <div class="col-12 col-lg-2 text-center py-lg-0 game-kickoff-status px-3">
# <div class="fw-bold text-wrap">
# 			09/27/20 01:00 PM EDT
# 		</div>
# <div class="text-center text-secondary flex-centered">
# <span>Final</span>
#
# 		</div>
# </div>
# <div class="col-12 col-lg-3 text-center flex-centered flex-column flex-lg-row">
# <div class="d-flex justify-content-center align-items-center col-lg-12 px-3">
# <div class="team-game-box justify-content-lg-end">
# <div class="flex-centered flex-column-reverse flex-xxl-row flex-grow-1">
# <div class="flex-centered flex-column me-1 ms-xxl-auto">
# <a class="text-dark" href="/team/titans" target="_blank" title="Click to see more details about Tennessee Titans">
# <img class="helmet" src="/uploads/team/away_helmet/5/small_tennessee.png"/>
# </a> <span class="fw-bold">Titans</span>
# </div>
# </div>
# <div class="game-points ps-1 pe-2"></div>
# </div>
# <span class="fw-bold teams-separator">@</span>
# <div class="team-game-box">
# <div class="game-points pe-1 ps-2"></div>
# <div class="flex-centered flex-column flex-xxl-row flex-grow-1">
# <div class="flex-centered flex-column me-xxl-auto">
# <a class="text-dark" href="/team/vikings" target="_blank" title="Click to see more details about Minnesota Vikings">
# <img class="helmet" src="/uploads/team/home_helmet/25/small_h_minnesota.png"/>
# </a> <span class="fw-bold ms-1">Vikings</span>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-12 col-lg-7 flex-centered info-game-box pe-3 rounded-end">
# <div class="row flex-centered py-3 py-lg-2 flex-column flex-sm-row game-info w-100">
# <div class="text-center col-12 col-lg-2">
# <a class="text-dark" href="/games/2020/week-3/titans-at-vikings" target="_blank" title="Click to see more details about Titans at Vikings">
# <div class="image-container">
# <img class="game-box-weather-image bg-day rounded" src="/climates/partly-cloudy-day.png"/>
# </div>
# </a> </div>
# <div class="text-break #&lt;WeatherReport:0x0000556abb1bd778&gt; col-md-4 d-flex text-center justify-content-center flex-column">
# <div class="mx-2"><span class="">63 °F</span></div>
# <div class="mx-2"><span class="">Partly Cloudy</span></div>
# </div>
# <div class="text-break col-md-4 mb-1 px-1 flex-centered">
# <span class="material-icons icon-weather">air</span> <span class="">11 mph  <span class="material-icons md-18">west</span>  W</span>
# </div>
# <div class="col-md-4 col-lg-2 mb-2 mb-md-0 px-1 flex-centered justify-content-center justify-content-lg-start">
# <span class="material-icons outlined md-18">tv</span> <span class="text-center text-sm-start">CBS</span>
# </div>
# </div>
# </div>
# </div>
# <div class="game-box w-100 d-flex flex-column flex-lg-row align-items-center shadow-box rounded my-2 py-1" style="">
# <div class="col-12 col-lg-2 text-center py-lg-0 game-kickoff-status px-3">
# <div class="fw-bold text-wrap">
# 			09/27/20 01:00 PM EDT
# 		</div>
# <div class="text-center text-secondary flex-centered">
# <span>Final</span>
#
# 		</div>
# </div>
# <div class="col-12 col-lg-3 text-center flex-centered flex-column flex-lg-row">
# <div class="d-flex justify-content-center align-items-center col-lg-12 px-3">
# <div class="team-game-box justify-content-lg-end">
# <div class="flex-centered flex-column-reverse flex-xxl-row flex-grow-1">
# <div class="flex-centered flex-column me-1 ms-xxl-auto">
# <a class="text-dark" href="/team/washington" target="_blank" title="Click to see more details about Washington Washington">
# <img class="helmet" src="/uploads/team/away_helmet/7/small_washington.png"/>
# </a> <span class="fw-bold">Washington</span>
# </div>
# </div>
# <div class="game-points ps-1 pe-2"></div>
# </div>
# <span class="fw-bold teams-separator">@</span>
# <div class="team-game-box">
# <div class="game-points pe-1 ps-2"></div>
# <div class="flex-centered flex-column flex-xxl-row flex-grow-1">
# <div class="flex-centered flex-column me-xxl-auto">
# <a class="text-dark" href="/team/browns" target="_blank" title="Click to see more details about Cleveland Browns">
# <img class="helmet" src="/uploads/team/home_helmet/13/small_h_cleveland.png"/>
# </a> <span class="fw-bold ms-1">Browns</span>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-12 col-lg-7 flex-centered info-game-box pe-3 rounded-end">
# <div class="row flex-centered py-3 py-lg-2 flex-column flex-sm-row game-info w-100">
# <div class="text-center col-12 col-lg-2">
# <a class="text-dark" href="/games/2020/week-3/football%20team-at-browns" target="_blank" title="Click to see more details about Football Team at Browns">
# <div class="image-container">
# <img class="game-box-weather-image bg-day rounded" src="/climates/clear-day.png"/>
# </div>
# </a> </div>
# <div class="text-break #&lt;WeatherReport:0x0000556aba6c7d50&gt; col-md-4 d-flex text-center justify-content-center flex-column">
# <div class="mx-2"><span class="">77 °F</span></div>
# <div class="mx-2"><span class="">Clear</span></div>
# </div>
# <div class="text-break col-md-4 mb-1 px-1 flex-centered">
# <span class="material-icons icon-weather">air</span> <span class="">13 mph  <span class="material-icons md-18">south_west</span>  SW</span>
# </div>
# <div class="col-md-4 col-lg-2 mb-2 mb-md-0 px-1 flex-centered justify-content-center justify-content-lg-start">
# <span class="material-icons outlined md-18">tv</span> <span class="text-center text-sm-start">FOX</span>
# </div>
# </div>
# </div>
# </div>
# <div class="game-box w-100 d-flex flex-column flex-lg-row align-items-center shadow-box rounded my-2 py-1" style="">
# <div class="col-12 col-lg-2 text-center py-lg-0 game-kickoff-status px-3">
# <div class="fw-bold text-wrap">
# 			09/27/20 01:00 PM EDT
# 		</div>
# <div class="text-center text-secondary flex-centered">
# <span>Final</span>
#
# 		</div>
# </div>
# <div class="col-12 col-lg-3 text-center flex-centered flex-column flex-lg-row">
# <div class="d-flex justify-content-center align-items-center col-lg-12 px-3">
# <div class="team-game-box justify-content-lg-end">
# <div class="flex-centered flex-column-reverse flex-xxl-row flex-grow-1">
# <div class="flex-centered flex-column me-1 ms-xxl-auto">
# <a class="text-dark" href="/team/rams" target="_blank" title="Click to see more details about Los Angeles Rams">
# <img class="helmet" src="/uploads/team/away_helmet/6/small_la.png"/>
# </a> <span class="fw-bold">Rams</span>
# </div>
# </div>
# <div class="game-points ps-1 pe-2"></div>
# </div>
# <span class="fw-bold teams-separator">@</span>
# <div class="team-game-box">
# <div class="game-points pe-1 ps-2"></div>
# <div class="flex-centered flex-column flex-xxl-row flex-grow-1">
# <div class="flex-centered flex-column me-xxl-auto">
# <a class="text-dark" href="/team/bills" target="_blank" title="Click to see more details about Buffalo Bills">
# <img class="helmet" src="/uploads/team/home_helmet/3/small_h_buffalo.png"/>
# </a> <span class="fw-bold ms-1">Bills</span>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-12 col-lg-7 flex-centered info-game-box pe-3 rounded-end">
# <div class="row flex-centered py-3 py-lg-2 flex-column flex-sm-row game-info w-100">
# <div class="text-center col-12 col-lg-2">
# <a class="text-dark" href="/games/2020/week-3/rams-at-bills" target="_blank" title="Click to see more details about Rams at Bills">
# <div class="image-container">
# <img class="game-box-weather-image bg-day rounded" src="/climates/clear-day.png"/>
# </div>
# </a> </div>
# <div class="text-break #&lt;WeatherReport:0x0000556abac7ad88&gt; col-md-4 d-flex text-center justify-content-center flex-column">
# <div class="mx-2"><span class="">75 °F</span></div>
# <div class="mx-2"><span class="">Clear</span></div>
# </div>
# <div class="text-break col-md-4 mb-1 px-1 flex-centered">
# <span class="material-icons icon-weather">air</span> <span class="">13 mph  <span class="material-icons md-18">south_west</span>  SW</span>
# </div>
# <div class="col-md-4 col-lg-2 mb-2 mb-md-0 px-1 flex-centered justify-content-center justify-content-lg-start">
# <span class="material-icons outlined md-18">tv</span> <span class="text-center text-sm-start">FOX</span>
# </div>
# </div>
# </div>
# </div>
# <div class="game-box w-100 d-flex flex-column flex-lg-row align-items-center shadow-box rounded my-2 py-1" style="">
# <div class="col-12 col-lg-2 text-center py-lg-0 game-kickoff-status px-3">
# <div class="fw-bold text-wrap">
# 			09/27/20 01:00 PM EDT
# 		</div>
# <div class="text-center text-secondary flex-centered">
# <span>Final</span>
#
# 		</div>
# </div>
# <div class="col-12 col-lg-3 text-center flex-centered flex-column flex-lg-row">
# <div class="d-flex justify-content-center align-items-center col-lg-12 px-3">
# <div class="team-game-box justify-content-lg-end">
# <div class="flex-centered flex-column-reverse flex-xxl-row flex-grow-1">
# <div class="flex-centered flex-column me-1 ms-xxl-auto">
# <a class="text-dark" href="/team/bears" target="_blank" title="Click to see more details about Chicago Bears">
# <img class="helmet" src="/uploads/team/away_helmet/26/small_chicago.png"/>
# </a> <span class="fw-bold">Bears</span>
# </div>
# </div>
# <div class="game-points ps-1 pe-2"></div>
# </div>
# <span class="fw-bold teams-separator">@</span>
# <div class="team-game-box">
# <div class="game-points pe-1 ps-2"></div>
# <div class="flex-centered flex-column flex-xxl-row flex-grow-1">
# <div class="flex-centered flex-column me-xxl-auto">
# <a class="text-dark" href="/team/falcons" target="_blank" title="Click to see more details about Atlanta Falcons">
# <img class="helmet" src="/uploads/team/home_helmet/28/small_h_atlanta.png"/>
# </a> <span class="fw-bold ms-1">Falcons</span>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-12 col-lg-7 flex-centered info-game-box pe-3 rounded-end">
# <div class="row flex-centered py-3 py-lg-2 flex-column flex-sm-row game-info w-100">
# <div class="text-center col-12 col-lg-2">
# <a class="text-dark" href="/games/2020/week-3/bears-at-falcons" target="_blank" title="Click to see more details about Bears at Falcons">
# <div class="image-container">
# <img class="game-box-weather-image bg-day rounded" src="/climates/partly-cloudy-day.png"/>
# </div>
# </a> </div>
# <div class="text-break #&lt;WeatherReport:0x0000556ab9801118&gt; col-md-4 d-flex text-center justify-content-center flex-column">
# <div class="mx-2"><span class="">79 °F</span></div>
# <div class="mx-2"><span class="">Partly Cloudy</span></div>
# </div>
# <div class="text-break col-md-4 mb-1 px-1 flex-centered">
# <span class="material-icons icon-weather">air</span> <span class="">3 mph  <span class="material-icons md-18">south_west</span>  SW</span>
# </div>
# <div class="col-md-4 col-lg-2 mb-2 mb-md-0 px-1 flex-centered justify-content-center justify-content-lg-start">
# <span class="material-icons outlined md-18">tv</span> <span class="text-center text-sm-start">FOX</span>
# </div>
# </div>
# </div>
# </div>
# <div class="game-box w-100 d-flex flex-column flex-lg-row align-items-center shadow-box rounded my-2 py-1" style="">
# <div class="col-12 col-lg-2 text-center py-lg-0 game-kickoff-status px-3">
# <div class="fw-bold text-wrap">
# 			09/27/20 04:04 PM EDT
# 		</div>
# <div class="text-center text-secondary flex-centered">
# <span>Final</span>
#
# 		</div>
# </div>
# <div class="col-12 col-lg-3 text-center flex-centered flex-column flex-lg-row">
# <div class="d-flex justify-content-center align-items-center col-lg-12 px-3">
# <div class="team-game-box justify-content-lg-end">
# <div class="flex-centered flex-column-reverse flex-xxl-row flex-grow-1">
# <div class="flex-centered flex-column me-1 ms-xxl-auto">
# <a class="text-dark" href="/team/panthers" target="_blank" title="Click to see more details about Carolina Panthers">
# <img class="helmet" src="/uploads/team/away_helmet/27/small_Carolina_Phanters.png"/>
# </a> <span class="fw-bold">Panthers</span>
# </div>
# </div>
# <div class="game-points ps-1 pe-2"></div>
# </div>
# <span class="fw-bold teams-separator">@</span>
# <div class="team-game-box">
# <div class="game-points pe-1 ps-2"></div>
# <div class="flex-centered flex-column flex-xxl-row flex-grow-1">
# <div class="flex-centered flex-column me-xxl-auto">
# <a class="text-dark" href="/team/chargers" target="_blank" title="Click to see more details about Los Angeles Chargers">
# <img class="helmet" src="/uploads/team/home_helmet/20/small_h_la.png"/>
# </a> <span class="fw-bold ms-1">Chargers</span>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-12 col-lg-7 flex-centered info-game-box pe-3 rounded-end">
# <div class="row flex-centered py-3 py-lg-2 flex-column flex-sm-row game-info w-100">
# <div class="text-center col-12 col-lg-2">
# <a class="text-dark" href="/games/2020/week-3/panthers-at-chargers" target="_blank" title="Click to see more details about Panthers at Chargers">
# <div class="image-container">
# <img class="game-box-weather-image bg-day rounded" src="/climates/clear-day.png"/>
# </div>
# </a> </div>
# <div class="text-break #&lt;WeatherReport:0x0000556abace8fe0&gt; col-md-4 d-flex text-center justify-content-center flex-column">
# <div class="mx-2"><span class="">75 °F</span></div>
# <div class="mx-2"><span class="">Clear</span></div>
# </div>
# <div class="text-break col-md-4 mb-1 px-1 flex-centered">
# <span class="material-icons icon-weather">air</span> <span class="">5 mph  <span class="material-icons md-18">south_west</span>  SW</span>
# </div>
# <div class="col-md-4 col-lg-2 mb-2 mb-md-0 px-1 flex-centered justify-content-center justify-content-lg-start">
# <span class="material-icons outlined md-18">tv</span> <span class="text-center text-sm-start">CBS</span>
# </div>
# </div>
# </div>
# </div>
# <div class="game-box w-100 d-flex flex-column flex-lg-row align-items-center shadow-box rounded my-2 py-1" style="">
# <div class="col-12 col-lg-2 text-center py-lg-0 game-kickoff-status px-3">
# <div class="fw-bold text-wrap">
# 			09/27/20 04:04 PM EDT
# 		</div>
# <div class="text-center text-secondary flex-centered">
# <span>Final</span>
#
# 		</div>
# </div>
# <div class="col-12 col-lg-3 text-center flex-centered flex-column flex-lg-row">
# <div class="d-flex justify-content-center align-items-center col-lg-12 px-3">
# <div class="team-game-box justify-content-lg-end">
# <div class="flex-centered flex-column-reverse flex-xxl-row flex-grow-1">
# <div class="flex-centered flex-column me-1 ms-xxl-auto">
# <a class="text-dark" href="/team/jets" target="_blank" title="Click to see more details about New York Jets">
# <img class="helmet" src="/uploads/team/away_helmet/4/small_new_york.png"/>
# </a> <span class="fw-bold">Jets</span>
# </div>
# </div>
# <div class="game-points ps-1 pe-2"></div>
# </div>
# <span class="fw-bold teams-separator">@</span>
# <div class="team-game-box">
# <div class="game-points pe-1 ps-2"></div>
# <div class="flex-centered flex-column flex-xxl-row flex-grow-1">
# <div class="flex-centered flex-column me-xxl-auto">
# <a class="text-dark" href="/team/colts" target="_blank" title="Click to see more details about Indianapolis Colts">
# <img class="helmet" src="/uploads/team/home_helmet/16/small_h_indianapolis.png"/>
# </a> <span class="fw-bold ms-1">Colts</span>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-12 col-lg-7 flex-centered info-game-box pe-3 rounded-end">
# <div class="row flex-centered py-3 py-lg-2 flex-column flex-sm-row game-info w-100">
# <div class="text-center col-12 col-lg-2">
# <a class="text-dark" href="/games/2020/week-3/jets-at-colts" target="_blank" title="Click to see more details about Jets at Colts">
# <div class="image-container">
# <img class="game-box-weather-image bg-day rounded" src="/climates/clear-day.png"/>
# </div>
# </a> </div>
# <div class="text-break #&lt;WeatherReport:0x0000556abb05f2c8&gt; col-md-4 d-flex text-center justify-content-center flex-column">
# <div class="mx-2"><span class="">77 °F</span></div>
# <div class="mx-2"><span class="">Clear</span></div>
# </div>
# <div class="text-break col-md-4 mb-1 px-1 flex-centered">
# <span class="material-icons icon-weather">air</span> <span class="">10 mph  <span class="material-icons md-18">south_west</span>  SW</span>
# </div>
# <div class="col-md-4 col-lg-2 mb-2 mb-md-0 px-1 flex-centered justify-content-center justify-content-lg-start">
# <span class="material-icons outlined md-18">tv</span> <span class="text-center text-sm-start">CBS</span>
# </div>
# </div>
# </div>
# </div>
# <div class="game-box w-100 d-flex flex-column flex-lg-row align-items-center shadow-box rounded my-2 py-1" style="">
# <div class="col-12 col-lg-2 text-center py-lg-0 game-kickoff-status px-3">
# <div class="fw-bold text-wrap">
# 			09/27/20 04:25 PM EDT
# 		</div>
# <div class="text-center text-secondary flex-centered">
# <span>Final</span>
#
# 		</div>
# </div>
# <div class="col-12 col-lg-3 text-center flex-centered flex-column flex-lg-row">
# <div class="d-flex justify-content-center align-items-center col-lg-12 px-3">
# <div class="team-game-box justify-content-lg-end">
# <div class="flex-centered flex-column-reverse flex-xxl-row flex-grow-1">
# <div class="flex-centered flex-column me-1 ms-xxl-auto">
# <a class="text-dark" href="/team/cowboys" target="_blank" title="Click to see more details about Dallas Cowboys">
# <img class="helmet" src="/uploads/team/away_helmet/10/small_dallas.png"/>
# </a> <span class="fw-bold">Cowboys</span>
# </div>
# </div>
# <div class="game-points ps-1 pe-2"></div>
# </div>
# <span class="fw-bold teams-separator">@</span>
# <div class="team-game-box">
# <div class="game-points pe-1 ps-2"></div>
# <div class="flex-centered flex-column flex-xxl-row flex-grow-1">
# <div class="flex-centered flex-column me-xxl-auto">
# <a class="text-dark" href="/team/seahawks" target="_blank" title="Click to see more details about Seattle Seahawks">
# <img class="helmet" src="/uploads/team/home_helmet/31/small_h_seattle.png"/>
# </a> <span class="fw-bold ms-1">Seahawks</span>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-12 col-lg-7 flex-centered info-game-box pe-3 rounded-end">
# <div class="row flex-centered py-3 py-lg-2 flex-column flex-sm-row game-info w-100">
# <div class="text-center col-12 col-lg-2">
# <a class="text-dark" href="/games/2020/week-3/cowboys-at-seahawks" target="_blank" title="Click to see more details about Cowboys at Seahawks">
# <div class="image-container">
# <img class="game-box-weather-image bg-day rounded" src="/climates/clear-day.png"/>
# </div>
# </a> </div>
# <div class="text-break #&lt;WeatherReport:0x0000556abc3ec4a8&gt; col-md-4 d-flex text-center justify-content-center flex-column">
# <div class="mx-2"><span class="">64 °F</span></div>
# <div class="mx-2"><span class="">Clear</span></div>
# </div>
# <div class="text-break col-md-4 mb-1 px-1 flex-centered">
# <span class="material-icons icon-weather">air</span> <span class="">3 mph  <span class="material-icons md-18">north</span>  N</span>
# </div>
# <div class="col-md-4 col-lg-2 mb-2 mb-md-0 px-1 flex-centered justify-content-center justify-content-lg-start">
# <span class="material-icons outlined md-18">tv</span> <span class="text-center text-sm-start">FOX</span>
# </div>
# </div>
# </div>
# </div>
# <div class="game-box w-100 d-flex flex-column flex-lg-row align-items-center shadow-box rounded my-2 py-1" style="">
# <div class="col-12 col-lg-2 text-center py-lg-0 game-kickoff-status px-3">
# <div class="fw-bold text-wrap">
# 			09/27/20 04:25 PM EDT
# 		</div>
# <div class="text-center text-secondary flex-centered">
# <span>Final</span>
#
# 		</div>
# </div>
# <div class="col-12 col-lg-3 text-center flex-centered flex-column flex-lg-row">
# <div class="d-flex justify-content-center align-items-center col-lg-12 px-3">
# <div class="team-game-box justify-content-lg-end">
# <div class="flex-centered flex-column-reverse flex-xxl-row flex-grow-1">
# <div class="flex-centered flex-column me-1 ms-xxl-auto">
# <a class="text-dark" href="/team/buccaneers" target="_blank" title="Click to see more details about Tampa Bay Buccaneers">
# <img class="helmet" src="/uploads/team/away_helmet/9/small_tampa_bay.png"/>
# </a> <span class="fw-bold">Buccaneers</span>
# </div>
# </div>
# <div class="game-points ps-1 pe-2"></div>
# </div>
# <span class="fw-bold teams-separator">@</span>
# <div class="team-game-box">
# <div class="game-points pe-1 ps-2"></div>
# <div class="flex-centered flex-column flex-xxl-row flex-grow-1">
# <div class="flex-centered flex-column me-xxl-auto">
# <a class="text-dark" href="/team/broncos" target="_blank" title="Click to see more details about Denver Broncos">
# <img class="helmet" src="/uploads/team/home_helmet/18/small_h_denver.png"/>
# </a> <span class="fw-bold ms-1">Broncos</span>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-12 col-lg-7 flex-centered info-game-box pe-3 rounded-end">
# <div class="row flex-centered py-3 py-lg-2 flex-column flex-sm-row game-info w-100">
# <div class="text-center col-12 col-lg-2">
# <a class="text-dark" href="/games/2020/week-3/buccaneers-at-broncos" target="_blank" title="Click to see more details about Buccaneers at Broncos">
# <div class="image-container">
# <img class="game-box-weather-image bg-day rounded" src="/climates/fog.png"/>
# </div>
# </a> </div>
# <div class="text-break #&lt;WeatherReport:0x0000556abc1a3138&gt; col-md-4 d-flex text-center justify-content-center flex-column">
# <div class="mx-2"><span class="">54 °F</span></div>
# <div class="mx-2"><span class="">Foggy</span></div>
# </div>
# <div class="text-break col-md-4 mb-1 px-1 flex-centered">
# <span class="material-icons icon-weather">air</span> <span class="">4 mph  <span class="material-icons md-18">north_east</span>  NE</span>
# </div>
# <div class="col-md-4 col-lg-2 mb-2 mb-md-0 px-1 flex-centered justify-content-center justify-content-lg-start">
# <span class="material-icons outlined md-18">tv</span> <span class="text-center text-sm-start">FOX</span>
# </div>
# </div>
# </div>
# </div>
# <div class="game-box w-100 d-flex flex-column flex-lg-row align-items-center shadow-box rounded my-2 py-1" style="">
# <div class="col-12 col-lg-2 text-center py-lg-0 game-kickoff-status px-3">
# <div class="fw-bold text-wrap">
# 			09/27/20 04:25 PM EDT
# 		</div>
# <div class="text-center text-secondary flex-centered">
# <span>Final</span>
#
# 		</div>
# </div>
# <div class="col-12 col-lg-3 text-center flex-centered flex-column flex-lg-row">
# <div class="d-flex justify-content-center align-items-center col-lg-12 px-3">
# <div class="team-game-box justify-content-lg-end">
# <div class="flex-centered flex-column-reverse flex-xxl-row flex-grow-1">
# <div class="flex-centered flex-column me-1 ms-xxl-auto">
# <a class="text-dark" href="/team/lions" target="_blank" title="Click to see more details about Detroit Lions">
# <img class="helmet" src="/uploads/team/away_helmet/23/small_detroit.png"/>
# </a> <span class="fw-bold">Lions</span>
# </div>
# </div>
# <div class="game-points ps-1 pe-2"></div>
# </div>
# <span class="fw-bold teams-separator">@</span>
# <div class="team-game-box">
# <div class="game-points pe-1 ps-2"></div>
# <div class="flex-centered flex-column flex-xxl-row flex-grow-1">
# <div class="flex-centered flex-column me-xxl-auto">
# <a class="text-dark" href="/team/cardinals" target="_blank" title="Click to see more details about Arizona Cardinals">
# <img class="helmet" src="/uploads/team/home_helmet/32/small_h_arizona.png"/>
# </a> <span class="fw-bold ms-1">Cardinals</span>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-12 col-lg-7 flex-centered info-game-box pe-3 rounded-end">
# <div class="row flex-centered py-3 py-lg-2 flex-column flex-sm-row game-info w-100">
# <div class="text-center col-12 col-lg-2">
# <a class="text-dark" href="/games/2020/week-3/lions-at-cardinals" target="_blank" title="Click to see more details about Lions at Cardinals">
# <div class="image-container">
# <img class="game-box-weather-image bg-day rounded" src="/climates/clear-day.png"/>
# </div>
# </a> </div>
# <div class="text-break #&lt;WeatherReport:0x0000556abbcce5e0&gt; col-md-4 d-flex text-center justify-content-center flex-column">
# <div class="mx-2"><span class="text-danger">98 °F</span></div>
# <div class="mx-2"><span class="">Clear</span></div>
# </div>
# <div class="text-break col-md-4 mb-1 px-1 flex-centered">
# <span class="material-icons icon-weather">air</span> <span class="">4 mph  <span class="material-icons md-18">south_west</span>  SW</span>
# </div>
# <div class="col-md-4 col-lg-2 mb-2 mb-md-0 px-1 flex-centered justify-content-center justify-content-lg-start">
# <span class="material-icons outlined md-18">tv</span> <span class="text-center text-sm-start">FOX</span>
# </div>
# </div>
# </div>
# </div>
# <div class="game-box w-100 d-flex flex-column flex-lg-row align-items-center shadow-box rounded my-2 py-1" style="">
# <div class="col-12 col-lg-2 text-center py-lg-0 game-kickoff-status px-3">
# <div class="fw-bold text-wrap">
# 			09/27/20 08:20 PM EDT
# 		</div>
# <div class="text-center text-secondary flex-centered">
# <span>Final</span>
#
# 		</div>
# </div>
# <div class="col-12 col-lg-3 text-center flex-centered flex-column flex-lg-row">
# <div class="d-flex justify-content-center align-items-center col-lg-12 px-3">
# <div class="team-game-box justify-content-lg-end">
# <div class="flex-centered flex-column-reverse flex-xxl-row flex-grow-1">
# <div class="flex-centered flex-column me-1 ms-xxl-auto">
# <a class="text-dark" href="/team/packers" target="_blank" title="Click to see more details about Green Bay Packers">
# <img class="helmet" src="/uploads/team/away_helmet/24/small_green_bay.png"/>
# </a> <span class="fw-bold">Packers</span>
# </div>
# </div>
# <div class="game-points ps-1 pe-2"></div>
# </div>
# <span class="fw-bold teams-separator">@</span>
# <div class="team-game-box">
# <div class="game-points pe-1 ps-2"></div>
# <div class="flex-centered flex-column flex-xxl-row flex-grow-1">
# <div class="flex-centered flex-column me-xxl-auto">
# <a class="text-dark" href="/team/saints" target="_blank" title="Click to see more details about New Orleans Saints">
# <img class="helmet" src="/uploads/team/home_helmet/29/small_h_new_orleans.png"/>
# </a> <span class="fw-bold ms-1">Saints</span>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-12 col-lg-7 flex-centered info-game-box pe-3 rounded-end">
# <div class="row flex-centered py-3 py-lg-2 flex-column flex-sm-row game-info w-100">
# <div class="text-center col-12 col-lg-2">
# <a class="text-dark" href="/games/2020/week-3/packers-at-saints" target="_blank" title="Click to see more details about Packers at Saints">
# <div class="image-container">
# <img class="game-box-weather-image bg-night rounded" src="/climates/clear-night.png"/>
# </div>
# </a> </div>
# <div class="text-break #&lt;WeatherReport:0x0000556abb9f3578&gt; col-md-4 d-flex text-center justify-content-center flex-column">
# <div class="mx-2"><span class="">79 °F</span></div>
# <div class="mx-2"><span class="">Clear</span></div>
# </div>
# <div class="text-break col-md-4 mb-1 px-1 flex-centered">
# <span class="material-icons icon-weather">air</span> <span class="">5 mph  <span class="material-icons md-18">south_east</span>  SE</span>
# </div>
# <div class="col-md-4 col-lg-2 mb-2 mb-md-0 px-1 flex-centered justify-content-center justify-content-lg-start">
# <span class="material-icons outlined md-18">tv</span> <span class="text-center text-sm-start">NBC</span>
# </div>
# </div>
# </div>
# </div>
# <div class="game-box w-100 d-flex flex-column flex-lg-row align-items-center shadow-box rounded my-2 py-1" style="">
# <div class="col-12 col-lg-2 text-center py-lg-0 game-kickoff-status px-3">
# <div class="fw-bold text-wrap">
# 			09/28/20 08:15 PM EDT
# 		</div>
# <div class="text-center text-secondary flex-centered">
# <span>Final</span>
#
# 		</div>
# </div>
# <div class="col-12 col-lg-3 text-center flex-centered flex-column flex-lg-row">
# <div class="d-flex justify-content-center align-items-center col-lg-12 px-3">
# <div class="team-game-box justify-content-lg-end">
# <div class="flex-centered flex-column-reverse flex-xxl-row flex-grow-1">
# <div class="flex-centered flex-column me-1 ms-xxl-auto">
# <a class="text-dark" href="/team/chiefs" target="_blank" title="Click to see more details about Kansas City Chiefs">
# <img class="helmet" src="/uploads/team/away_helmet/1/small_kansas_city.png"/>
# </a> <span class="fw-bold">Chiefs</span>
# </div>
# </div>
# <div class="game-points ps-1 pe-2"></div>
# </div>
# <span class="fw-bold teams-separator">@</span>
# <div class="team-game-box">
# <div class="game-points pe-1 ps-2"></div>
# <div class="flex-centered flex-column flex-xxl-row flex-grow-1">
# <div class="flex-centered flex-column me-xxl-auto">
# <a class="text-dark" href="/team/ravens" target="_blank" title="Click to see more details about Baltimore Ravens">
# <img class="helmet" src="/uploads/team/home_helmet/15/small_h_baltimore.png"/>
# </a> <span class="fw-bold ms-1">Ravens</span>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-12 col-lg-7 flex-centered info-game-box pe-3 rounded-end">
# <div class="row flex-centered py-3 py-lg-2 flex-column flex-sm-row game-info w-100">
# <div class="text-center col-12 col-lg-2">
# <a class="text-dark" href="/games/2020/week-3/chiefs-at-ravens" target="_blank" title="Click to see more details about Chiefs at Ravens">
# <div class="image-container">
# <img class="game-box-weather-image bg-night rounded" src="/climates/clear-night.png"/>
# </div>
# </a> </div>
# <div class="text-break #&lt;WeatherReport:0x0000556ab9171fa0&gt; col-md-4 d-flex text-center justify-content-center flex-column">
# <div class="mx-2"><span class="">72 °F</span></div>
# <div class="mx-2"><span class="">Clear</span></div>
# </div>
# <div class="text-break col-md-4 mb-1 px-1 flex-centered">
# <span class="material-icons icon-weather">air</span> <span class="">8 mph  <span class="material-icons md-18">south_east</span>  SE</span>
# </div>
# <div class="col-md-4 col-lg-2 mb-2 mb-md-0 px-1 flex-centered justify-content-center justify-content-lg-start">
# <span class="material-icons outlined md-18">tv</span> <span class="text-center text-sm-start">ESPN</span>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="container my-3 text-center overflow-hidden"><div style="max-width:100%"><script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script> <div id="gpt-passback"> <script>      window.googletag = window.googletag || {cmd: []};      googletag.cmd.push(function() {      googletag.defineSlot('/7103,22864402389/SMG_NFLWeather/728x90_1a/sports', [728, 90], 'gpt-passback').addService(googletag.pubads());      googletag.enableServices();      googletag.display('gpt-passback');      });    </script> </div></div></div>
# <ul class="nav nav-pills fixed-bottom" id="menu-nav-bottom2">
# <li class="nav-item item-footer">
# <a class="nav-link" href="/"><i class="font-icon material-icons">home</i></a>
# <p>Home</p>
# </li>
# <li class="nav-item item-footer">
# <a class="nav-link" href="/archive"><i class="font-icon material-icons">analytics</i></a>
# <p>Analytics</p>
# </li>
# <li class="nav-item item-footer">
# <a class="nav-link" href="/team_forecast"><i class="font-icon material-icons">sports_football</i></a>
# <p>Teams</p>
# </li>
# <li class="nav-item item-footer">
# <a class="nav-link" href="/stadium_forecast"><i class="font-icon material-icons">stadium</i></a>
# <p>Stadiums</p>
# </li>
# <li class="nav-item item-footer">
# <a class="nav-link" href="/pickem_leaders"><i class="font-icon material-icons">thumbs_up_down</i></a>
# <p>Pick'em Leaders</p>
# </li>
# <li class="nav-item item-footer">
# <a class="nav-link" href="/users/sign_in"><i class="font-icon material-icons">login</i></a>
# <p>Log In</p>
# </li>
# </ul>
# <footer class="text-center text-white mt-auto">
# <div class="container footer-leyend fl-top">
# <p class="m-0">
# <small>
#           © 2012 <a href="http://www.nflweather.com">NFLWeather.com™</a>is a member of the USA Today Sports Media Group.
#       </small>
# </p>
# <p class="m-0"><small>NFLWeather.com is not affiliated with the National Football League</small></p>
# </div>
# <div class="container footer-buttons">
# <ul class="nav nav-footer justify-content-center">
# <a class="nav-item item-footer nav-link" href="/">
# <i class="font-icon material-icons">home</i>
# <p class="mt-1">HOME</p>
# </a> <a class="nav-item item-footer nav-link" href="/archive" target="_blank">
# <i class="font-icon material-icons">analytics</i>
# <p class="mt-1">ANALYTICS</p>
# </a> <a class="nav-item item-footer nav-link" href="/team_forecast" target="_blank">
# <i class="font-icon material-icons">sports_football</i>
# <p class="mt-1">TEAMS</p>
# </a> <a class="nav-item item-footer nav-link" href="/stadium_forecast" target="_blank">
# <i class="font-icon material-icons">stadium</i>
# <p class="mt-1">STADIUMS</p>
# </a> <a class="nav-item item-footer nav-link" href="/widgets" target="_blank">
# <i class="font-icon material-icons">widgets</i>
# <p class="mt-1">FREE WIDGETS</p>
# </a> <a class="nav-item item-footer nav-link" href="/partners" target="_blank">
# <i class="font-icon material-icons">handshake</i>
# <p class="mt-1">PARTNERS</p>
# </a> <a class="nav-item item-footer nav-link" href="/feedback" target="_blank">
# <i class="font-icon material-icons">chat</i>
# <p class="mt-1">FEEDBACK</p>
# </a> <a class="nav-item item-footer nav-link" href="/about" target="_blank">
# <i class="font-icon material-icons">info</i>
# <p class="mt-1">ABOUT NFLW</p>
# </a> </ul>
# </div>
# <div class="container footer-leyend fl-bottom pb-2">
# <p class="m-0">
# <small>
#           © 2012 <a href="http://www.nflweather.com">NFLWeather.com™</a> is a member of the USA Today Sports Media Group.
#       </small>
# </p>
# </div>
# </footer>
# <div class="modal" id="modal-subscription" tabindex="-1">
# <div class="modal-dialog rounded">
# <div class="modal-content rounded">
# <div class="modal-body rounded">
# <p></p>
# </div>
# </div>
# </div>
# </div>
# <div class="modal modal-lg fade nflwmodal text-white" id="nflwModal" tabindex="-1">
# <div class="modal-dialog">
# <div class="modal-content">
# <div class="modal-header">
# <h5 class="modal-title" id="nflwModalLabel">Modal title</h5>
# <button aria-label="Close" class="btn-close" data-bs-dismiss="modal" type="button"></button>
# </div>
# <div class="modal-body" id="nflwModalBody">
# <p>Modal body text goes here.</p>
# </div>
# <div class="modal-footer" id="nflwModalFooter">
# <button class="btn btn-secondary" data-bs-dismiss="modal" type="button">Close</button>
# <button class="btn btn-primary" type="button">Save changes</button>
# </div>
# </div>
# </div>
# </div>
# <div class="cookie-bar flex-wrap">
# <div class="mb-3 mb-xl-0">
# <p class="color-blue flex-centered"><span class="material-icons">cookie</span> <b>We responsibily use cookies to save your preferences</b></p>
# <span>NFLWeather<span style="font-size: 8px;vertical-align: text-top;"><sup>TM</sup></span> uses cookies to improve your user experience. By clicking "Accept All", you consent the use of these cookies. </span>
# </div>
# <div class="cookie-button"><a class="button-nflw" href="#" id="accept-cookies">Accept All</a></div>
# </div>
# <script>
#   $(document).ready(function(){
#     c = Cookies.get('cookies_accepted');
#     if (c != "true"){
#       $('.cookie-bar').css('display', 'flex')
#     }
#   });
#
#   $('#accept-cookies').click(()=>{
#     Cookies.set('cookies_accepted', 'true', { expires: 365 });
#     $('.cookie-bar').css('display', 'none')
#   })
# </script>
# <script src="https://cdn.jsdelivr.net/npm/ua-parser-js@1.0.36/src/ua-parser.min.js"></script>
# <script src="https://cdn.jsdelivr.net/npm/js-cookie@3.0.5/dist/js.cookie.min.js"></script>
# </body>
# </html>

# %%
soup.find_all("div", {"class": "game-points"}) # Points
# soup.find_all("a", {"class": "text-dark"})[8]["title"] # Teams
# soup.find_all("img", {"class": "game-box-weather-image"})[0]["src"] # Dome
# soup.find_all("div", {"class": "mx-2"}) # Weather
# soup.find_all("span", {"class": ""}) # Wind?
# weeks_raw = soup.find_all("option") # TO DO: incorporate weeks
# weeks = []
# for week in weeks_raw:
#     week_val = week["value"]
#     if week_val == "2023":
#         break
#     weeks.append(week_val)
#     print(week["value"])
# weeks
# Out:
# [<div class="game-points ps-1 pe-2"></div>,
#  <div class="game-points pe-1 ps-2"></div>,
#  <div class="game-points ps-1 pe-2"></div>,
#  <div class="game-points pe-1 ps-2"></div>,
#  <div class="game-points ps-1 pe-2"></div>,
#  <div class="game-points pe-1 ps-2"></div>,
#  <div class="game-points ps-1 pe-2"></div>,
#  <div class="game-points pe-1 ps-2"></div>,
#  <div class="game-points ps-1 pe-2"></div>,
#  <div class="game-points pe-1 ps-2"></div>,
#  <div class="game-points ps-1 pe-2"></div>,
#  <div class="game-points pe-1 ps-2"></div>,
#  <div class="game-points ps-1 pe-2"></div>,
#  <div class="game-points pe-1 ps-2"></div>,
#  <div class="game-points ps-1 pe-2"></div>,
#  <div class="game-points pe-1 ps-2"></div>,
#  <div class="game-points ps-1 pe-2"></div>,
#  <div class="game-points pe-1 ps-2"></div>,
#  <div class="game-points ps-1 pe-2"></div>,
#  <div class="game-points pe-1 ps-2"></div>,
#  <div class="game-points ps-1 pe-2"></div>,
#  <div class="game-points pe-1 ps-2"></div>,
#  <div class="game-points ps-1 pe-2"></div>,
#  <div class="game-points pe-1 ps-2"></div>,
#  <div class="game-points ps-1 pe-2"></div>,
#  <div class="game-points pe-1 ps-2"></div>,
#  <div class="game-points ps-1 pe-2"></div>,
#  <div class="game-points pe-1 ps-2"></div>,
#  <div class="game-points ps-1 pe-2"></div>,
#  <div class="game-points pe-1 ps-2"></div>,
#  <div class="game-points ps-1 pe-2"></div>,
#  <div class="game-points pe-1 ps-2"></div>]

# %% [markdown]
# ### Get links to player profiles for each player

# %%
# Pages with player names use first letter of last names
alphabet = list(string.ascii_lowercase)
player_name_link_df = pd.DataFrame()

# Loop through alphabet, get names and links for all players
for letter in alphabet:
    # Request URL, call BeautifulSoup
    webpage = "https://en.hispanosnba.com/players/nba-all/" + letter
    response = requests.get(webpage)
    if response.status_code == 404: # Some letters may not have pages, skip them
        continue 
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Get relevant part of webpage
    players = soup.find_all("table", {"class": "tblprm"})[0]
    player_name_links = players.find_all("a")

    # Loop through and add names, links
    for player in player_name_links:
        player_title = player["title"]
        player_link = player["href"]
        df = pd.DataFrame({'name': [player_title], 'link': [player_link]})
        player_name_link_df = pd.concat([player_name_link_df, df])
            
    # Set time buffer so as to not trigger any issues visiting website
    time.sleep(1)
